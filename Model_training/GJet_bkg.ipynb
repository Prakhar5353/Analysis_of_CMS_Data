# %%
import pandas as pd

# %%
df_gjet = pd.read_parquet('gjet_bkg.parquet',engine = 'pyarrow')

df_gjet['class'] = [0]*324769
df_gjet
# Out:
#        lead_dEscaleDown  lead_dEscaleUp  lead_dEsigmaDown  lead_dEsigmaUp  \
# entry
# 0                   0.0             0.0         -0.000114        0.000114
# 1                   0.0             0.0         -0.002693        0.002693
# 2                   0.0             0.0         -0.001022        0.001022
# 3                   0.0             0.0         -0.000214        0.000210
# 4                   0.0             0.0          0.007462       -0.007462
# ...                 ...             ...               ...             ...
# 31496               0.0             0.0          0.059937       -0.059937
# 31497               0.0             0.0         -0.001404        0.001408
# 31498               0.0             0.0         -0.023132        0.023132
# 31499               0.0             0.0         -0.009430        0.009430
# 31500               0.0             0.0          0.001137       -0.001122
#
#        lead_eCorr  lead_energyErr  lead_energyRaw  lead_esEffSigmaRR  \
# entry
# 0        0.999406       21.000000       22.421875                0.0
# 1        0.988558        1.015625       49.843750                0.0
# 2        0.996125        3.781250       46.843750                0.0
# 3        0.998877        0.593750       51.281250                0.0
# 4        1.004728        4.375000      105.937500                0.0
# ...           ...             ...             ...                ...
# 31496    1.023344        4.312500      172.375000                0.0
# 31497    0.993161        0.656250       56.093750                0.0
# 31498    0.981691        5.812500       82.875000                0.0
# 31499    0.990260       58.500000      163.250000                0.0
# 31500    1.002679        1.843750       91.250000                0.0
#
#        lead_esEnergyOverRawE  lead_eta  ...  genWeight         dZ  \
# entry                                   ...
# 0                        0.0 -0.485352  ...        1.0  -0.000893
# 1                        0.0  0.123032  ...        1.0 -10.178955
# 2                        0.0 -0.353638  ...        1.0  -3.678665
# 3                        0.0  0.057533  ...        1.0   2.736404
# 4                        0.0  1.169922  ...        1.0  -0.506714
# ...                      ...       ...  ...        ...        ...
# 31496                    0.0  1.356689  ...        1.0  -0.000793
# 31497                    0.0  0.951904  ...        1.0   0.000031
# 31498                    0.0  1.132812  ...        1.0  -0.001343
# 31499                    0.0  0.981567  ...        1.0  -0.000664
# 31500                    0.0 -0.697144  ...        1.0  -0.000549
#
#        HTXS_Higgs_pt  HTXS_Higgs_y  HTXS_njets30  HTXS_stage_0  \
# entry
# 0                0.0           NaN             0             0
# 1                0.0           NaN             0             0
# 2                0.0           NaN             0             0
# 3                0.0           NaN             0             0
# 4                0.0           NaN             0             0
# ...              ...           ...           ...           ...
# 31496            0.0           NaN             0             0
# 31497            0.0           NaN             0             0
# 31498            0.0           NaN             0             0
# 31499            0.0           NaN             0             0
# 31500            0.0           NaN             0             0
#
#        weight_central    weight  sigma_m_over_m  class
# entry
# 0            0.930848  0.930848        0.245624      0
# 1            0.840954  0.840954        0.017361      0
# 2            1.031788  1.031788        0.033951      0
# 3            0.721791  0.721791        0.033220      0
# 4            1.214474  1.214474        0.020582      0
# ...               ...       ...             ...    ...
# 31496        1.014182  1.014182        0.013333      0
# 31497        0.913400  0.913400        0.015258      0
# 31498        0.964378  0.964378        0.036028      0
# 31499        0.872149  0.872149        0.137598      0
# 31500        0.931968  0.931968        0.011421      0
#
# [324769 rows x 161 columns]

# %%
df_signal = pd.read_parquet('GGH_125_2017UL.parquet',engine = 'pyarrow')
#df_signal
df_signal['class'] = [1]*1453389
df_signal = df_signal.sample(frac=1)
df_signal = df_signal.head(324769)

# %%
df = pd.concat([df_gjet,df_signal],axis=0,join = 'outer')
df = df.sample(frac = 1)
df
# Out:
#          lead_dEscaleDown  lead_dEscaleUp  lead_dEsigmaDown  lead_dEsigmaUp  \
# 19670                 0.0             0.0         -0.000134        0.000134
# 9785                  0.0             0.0         -0.000320        0.000305
# 26665                 0.0             0.0          0.002144       -0.002144
# 30181                 0.0             0.0          0.005280       -0.005264
# 60379                 0.0             0.0         -0.000526        0.000526
# ...                   ...             ...               ...             ...
# 1244780               0.0             0.0          0.000572       -0.000572
# 736537                0.0             0.0          0.001602       -0.001595
# 1243873               0.0             0.0          0.000542       -0.000534
# 30403                 0.0             0.0         -0.001900        0.001907
# 1321126               0.0             0.0         -0.003845        0.003845
#
#          lead_eCorr  lead_energyErr  lead_energyRaw  lead_esEffSigmaRR  \
# 19670      0.999379        0.664062        60.15625           0.000000
# 9785       0.998244        1.234375        77.18750           0.000000
# 26665      1.007888        0.984375        76.18750           0.000000
# 30181      1.007041        5.812500       140.37500           4.090380
# 60379      0.997215        2.031250        77.43750           0.000000
# ...             ...             ...             ...                ...
# 1244780    1.002661        1.937500        59.71875           0.000000
# 736537     1.005561        0.875000        79.25000           0.000000
# 1243873    1.001160        3.875000        90.75000           0.000000
# 30403      0.991489        1.500000        97.81250           0.000000
# 1321126    0.997588        4.625000       204.12500           2.985606
#
#          lead_esEnergyOverRawE  lead_eta  ...   genWeight        dZ  \
# 19670                 0.000000 -0.876953  ...    1.000000 -2.006351
# 9785                  0.000000  1.194580  ...    1.000000  0.000935
# 26665                 0.000000 -0.751709  ...    1.000000  0.000816
# 30181                 0.030443  2.070312  ...    1.000000  0.000610
# 60379                 0.000000 -1.134277  ...  192.759155  0.969360
# ...                        ...       ...  ...         ...       ...
# 1244780               0.000000  0.149170  ...  192.759155  0.000183
# 736537                0.000000  0.808350  ...  192.759155  0.382853
# 1243873               0.000000  0.915039  ...  192.759155 -0.001526
# 30403                 0.000000  1.327148  ...    1.000000  0.001663
# 1321126               0.021860 -1.998779  ...  192.759155  1.989410
#
#          HTXS_Higgs_pt  HTXS_Higgs_y  HTXS_njets30  HTXS_stage_0  \
# 19670         0.000000           NaN             0             0
# 9785          0.000000           NaN             0             0
# 26665         0.000000           NaN             0             0
# 30181         0.000000           NaN             0             0
# 60379         7.250244     -0.346436             0            11
# ...                ...           ...           ...           ...
# 1244780      30.803711     -0.426392             1            11
# 736537       15.832520      1.348877             0            11
# 1243873      52.486328      1.103027             2            11
# 30403         0.000000           NaN             0             0
# 1321126       8.997559     -1.526123             0            11
#
#          weight_central      weight  sigma_m_over_m  class
# 19670          0.904680    0.904680        0.191232      0
# 9785           0.866778    0.866778        0.041378      0
# 26665          1.005404    1.005404        0.011727      0
# 30181          0.883797    0.883797        0.020033      0
# 60379          0.995216  191.836947        0.014575      1
# ...                 ...         ...             ...    ...
# 1244780        0.950209  183.161569        0.017758      1
# 736537         0.963705  185.762914        0.012225      1
# 1243873        0.940133  181.219261        0.022097      1
# 30403          0.875766    0.875766        0.009614      0
# 1321126        0.930063  179.278208        0.016194      1
#
# [649538 rows x 161 columns]

# %%
df['subleadptom'] = df['sublead_pt']/df['mass']
df['leadptom'] = df['lead_pt']/df['mass']

# %%
#from sklearn.model_selection import train_test_split
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
import matplotlib.pyplot as plt
import scienceplots
import scienceplots
plt.style.use(['science', 'notebook'])
from sklearn.preprocessing import StandardScaler
import seaborn as sns
import numpy as np

# %%
target = df['class']
features = df[['sublead_mvaID','sigmarv','lead_mvaID','sublead_eta','subleadptom','vtxprob','lead_eta','sigmawv','leadptom','CosPhi','PV_chi2','PV_Score']]
features
# Out:
#          sublead_mvaID   sigmarv  lead_mvaID  sublead_eta  subleadptom  \
# 19670        -0.997588  0.191232    0.970088     0.196960     0.358884
# 9785          0.125157  0.041378    0.942934     1.614746     0.382822
# 26665        -0.747542  0.011727    0.760537    -0.837036     0.343617
# 30181         0.983457  0.020033   -0.986457     0.750732     0.440867
# 60379         0.943569  0.014575    0.951253     0.474365     0.358757
# ...                ...       ...         ...          ...          ...
# 1244780       0.886639  0.017758    0.781709    -1.182129     0.355937
# 736537        0.910606  0.012225    0.821277     2.042969     0.362224
# 1243873       0.910928  0.022097   -0.893879     1.340332     0.485279
# 30403         0.964791  0.009614    0.912459    -0.338623     0.417559
# 1321126       0.656949  0.016194    0.880283    -1.043213     0.442833
#
#          vtxprob  lead_eta   sigmawv  leadptom    CosPhi   PV_chi2  PV_Score
# 19670      0.999 -0.876953  0.191396  0.534744 -0.971179  0.681641     182.0
# 9785       0.999  1.194580  0.044168  0.643712 -0.934713  0.644531   77568.0
# 26665      0.999 -0.751709  0.021310  0.726727 -0.998038  0.863281     292.0
# 30181      0.999  2.070312  0.028516  0.447837 -0.527205  0.808594   10944.0
# 60379      0.999 -1.134277  0.015458  0.388615 -0.987774  0.607422     132.0
# ...          ...       ...       ...       ...       ...       ...       ...
# 1244780    0.999  0.149170  0.020525  0.484755 -0.874265  0.744141     485.0
# 736537     0.999  0.808350  0.022796  0.483133 -0.993145  0.771484     419.0
# 1243873    0.999  0.915039  0.028290  0.572437 -0.706310  0.775391    1028.0
# 30403      0.999  1.327148  0.014776  0.532460  0.492665  0.740234    1264.0
# 1321126    0.999 -1.998779  0.024037  0.455320 -0.988789  0.794922     134.0
#
# [649538 rows x 12 columns]

# %%
cols = features.columns
df_scaled = StandardScaler().fit(features)
dfsc = df_scaled.transform(features)
scaled_features = pd.DataFrame(dfsc,
                         columns=cols)
scaled_features.describe()
# Out:
#        sublead_mvaID       sigmarv    lead_mvaID   sublead_eta   subleadptom  \
# count   6.495380e+05  6.495380e+05  6.495380e+05  6.495380e+05  6.495380e+05
# mean    7.375253e-17 -6.898944e-17  5.344364e-17  2.736356e-17 -1.810977e-16
# std     1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00
# min    -1.854558e+00 -4.895932e-01 -2.158156e+00 -2.023473e+00 -6.625481e-01
# 25%    -8.567650e-01 -3.986105e-01 -3.910152e-01 -7.303032e-01 -4.378564e-01
# 50%     5.504118e-01 -2.918318e-01  5.457260e-01  2.616757e-03 -2.853767e-01
# 75%     8.035788e-01 -1.321562e-01  7.039690e-01  7.277023e-01 -1.146307e-01
# max     8.887716e-01  6.863391e+00  7.636744e-01  2.025915e+00  6.347171e+01
#
#             vtxprob      lead_eta       sigmawv      leadptom        CosPhi  \
# count  6.495380e+05  6.495380e+05  6.495380e+05  6.495380e+05  6.495380e+05
# mean   1.110223e-16 -2.813870e-17  1.105040e-16 -2.190968e-16  4.575116e-17
# std    0.000000e+00  1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00
# min    1.110223e-16 -2.034566e+00 -6.219390e-01 -6.578432e-01 -8.384790e-01
# 25%    1.110223e-16 -7.372048e-01 -3.707594e-01 -4.503578e-01 -8.086278e-01
# 50%    1.110223e-16  2.511587e-03 -2.582713e-01 -3.403198e-01 -5.651037e-01
# 75%    1.110223e-16  7.333902e-01 -1.228705e-01 -5.402635e-02  8.245816e-01
# max    1.110223e-16  2.033235e+00  6.931032e+00  5.517836e+01  1.916771e+00
#
#             PV_chi2      PV_Score
# count  6.495380e+05  6.495380e+05
# mean  -6.020715e-17  3.595374e-17
# std    1.000001e+00  1.000001e+00
# min   -3.536088e+00 -3.171133e-01
# 25%   -3.330132e-01 -3.029632e-01
# 50%   -2.303819e-02 -2.661777e-01
# 75%    2.869368e-01 -1.019724e-01
# max    5.495344e+02  7.236056e+01

# %%
target.describe()
# Out:
# count    649538.0
# mean          0.5
# std           0.5
# min           0.0
# 25%           0.0
# 50%           0.5
# 75%           1.0
# max           1.0
# Name: class, dtype: float64

# %%
class CustomDataset(Dataset):
    def __init__(self, inputs, targets):
        self.inputs = inputs
        self.targets = targets

    def __len__(self):
        return len(self.inputs)

    def __getitem__(self, idx):
        return self.inputs[idx], self.targets[idx]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(scaled_features, target,test_size = 0.2, random_state = 0,shuffle = True)
X_train.describe()
# Out:
#        sublead_mvaID        sigmarv     lead_mvaID    sublead_eta  \
# count  519630.000000  519630.000000  519630.000000  519630.000000
# mean       -0.000511      -0.000478       0.000478       0.000265
# std         1.000037       0.999324       0.999909       1.000190
# min        -1.854558      -0.489593      -2.158156      -2.023473
# 25%        -0.859297      -0.398673      -0.389292      -0.730798
# 50%         0.549629      -0.292011       0.546236       0.003552
# 75%         0.803497      -0.132495       0.704105       0.728098
# max         0.888772       6.834116       0.763674       2.025915
#
#          subleadptom       vtxprob       lead_eta        sigmawv  \
# count  519630.000000  5.196300e+05  519630.000000  519630.000000
# mean        0.001456  1.110223e-16      -0.000003      -0.000429
# std         1.005508  0.000000e+00       1.000054       0.999302
# min        -0.662546  1.110223e-16      -2.034566      -0.621939
# 25%        -0.437346  1.110223e-16      -0.737602      -0.370675
# 50%        -0.285097  1.110223e-16       0.001710      -0.258380
# 75%        -0.114337  1.110223e-16       0.733192      -0.123326
# max        63.471706  1.110223e-16       2.033235       6.901152
#
#             leadptom         CosPhi        PV_chi2       PV_Score
# count  519630.000000  519630.000000  519630.000000  519630.000000
# mean        0.000929       0.000633      -0.001245      -0.000572
# std         1.006598       0.999994       0.757862       0.994861
# min        -0.657843      -0.838479      -3.536088      -0.317113
# 25%        -0.450362      -0.808563      -0.333013      -0.302963
# 50%        -0.340282      -0.563702      -0.032431      -0.266301
# 75%        -0.053357       0.826138       0.286937      -0.101972
# max        55.178364       1.916771     228.513048      72.360557

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size = 0.0625, random_state = 42)
X_train.describe()
# Out:
#        sublead_mvaID        sigmarv     lead_mvaID    sublead_eta  \
# count  487153.000000  487153.000000  487153.000000  487153.000000
# mean       -0.000864      -0.000217       0.000871       0.000442
# std         1.000188       0.999852       0.999618       1.000059
# min        -1.854558      -0.489593      -2.158156      -2.023473
# 25%        -0.860416      -0.398658      -0.387825      -0.730501
# 50%         0.549605      -0.292098       0.546462       0.003690
# 75%         0.803503      -0.132705       0.704129       0.728691
# max         0.888772       6.834116       0.763674       2.025915
#
#          subleadptom       vtxprob       lead_eta        sigmawv  \
# count  487153.000000  4.871530e+05  487153.000000  487153.000000
# mean        0.001977  1.110223e-16      -0.000016      -0.000115
# std         1.006181  0.000000e+00       0.999992       0.999818
# min        -0.662546  1.110223e-16      -2.034566      -0.621939
# 25%        -0.437276  1.110223e-16      -0.737701      -0.370644
# 50%        -0.285016  1.110223e-16       0.001545      -0.258413
# 75%        -0.114105  1.110223e-16       0.733490      -0.123368
# max        63.471706  1.110223e-16       2.033235       6.901152
#
#             leadptom         CosPhi        PV_chi2       PV_Score
# count  487153.000000  487153.000000  487153.000000  487153.000000
# mean        0.001413       0.000609      -0.001175      -0.000359
# std         1.009611       1.000100       0.711772       0.997923
# min        -0.657843      -0.838479      -3.536088      -0.317113
# 25%        -0.450323      -0.808602      -0.333013      -0.302963
# 50%        -0.340064      -0.563905      -0.032431      -0.266301
# 75%        -0.052884       0.826594       0.286937      -0.101972
# max        55.178364       1.916771     228.513048      72.360557

# %%
y_train
# Out:
# 345149     1
# 9493       0
# 219585     1
# 1182218    1
# 391294     1
#           ..
# 29136      0
# 39039      0
# 39608      0
# 3503       0
# 24219      0
# Name: class, Length: 487153, dtype: int64

# %%
training_inputs, training_outputs = torch.tensor(X_train.values, dtype = torch.float).to(device),torch.tensor(y_train.values, dtype = torch.float).reshape(-1, 1).to(device)
validation_inputs, validation_outputs = torch.tensor(X_valid.values, dtype = torch.float).to(device),torch.tensor(y_valid.values, dtype = torch.float).reshape(-1, 1).to(device)
#training_outputs.reshape(-1, 1).shape

# %%
train_dataset = CustomDataset(training_inputs, training_outputs)
train_dataloader = DataLoader(train_dataset, batch_size=524, shuffle=True)

# %%
validation_dataset = CustomDataset(validation_inputs, validation_outputs)
validation_dataloader = DataLoader(validation_dataset, batch_size=80, shuffle=True)

# %%
class classifier(nn.Module):
    def __init__(self,layer,input_dim):
        super().__init__()
        self.layer = layer
        self.input_dim = input_dim
        
        self.hiddenlayer1 = nn.Linear(in_features = self.input_dim, out_features = self.layer[0])
        self.activ1 = nn.ReLU()
        self.hiddenlayer2 = nn.Linear(in_features = self.layer[0],out_features = self.layer[1])
        self.activ2 = nn.ReLU()
        self.hiddenlayer3 = nn.Linear(in_features = self.layer[1],out_features = self.layer[2])
        self.activ3 = nn.ReLU()
        self.hiddenlayer4 = nn.Linear(in_features = self.layer[2],out_features = self.layer[3])
        self.activ4 = nn.ReLU()
        self.hiddenlayer5 = nn.Linear(in_features = self.layer[3],out_features = self.layer[4])
        self.activ5 = nn.Sigmoid()
    def forward(self, inputs):
        out1 = self.hiddenlayer1(inputs)
        out2 = self.activ1(out1)
        out3 = self.hiddenlayer2(out2)
        out4 = self.activ2(out3)
        out5 = self.hiddenlayer3(out4)
        out6 = self.activ3(out5)
        out7 = self.hiddenlayer4(out6)
        out8 = self.activ4(out7)
        out9 = self.hiddenlayer5(out8)
        output = self.activ5(out9)
        return output

# %%
hidden_layers = [20,10,5,2,1]
model = classifier(hidden_layers, 12)
model.to(device)
optimizer = torch.optim.Adam(model.parameters(), lr = 0.0001)
criterion = torch.nn.BCELoss()
n_epochs = 500
valid_loss = []
train_loss = []
for epoch in range(n_epochs):
        print(f"Epoch {epoch + 1}/{n_epochs}")
        t_loss = []
        for step, data in enumerate(train_dataloader):
            optimizer.zero_grad()
            prediction = model.forward(data[0])
            #print(prediction)
            #print("data: ",data[1])
            loss = criterion(prediction, data[1])
            loss.backward()
            optimizer.step()
            t_loss.append(loss)
        train_loss.append(torch.tensor(t_loss).mean())
        
        v_loss = []
        for v_step, data in enumerate(validation_dataloader):
            with torch.no_grad():
                _prediction = model.forward(data[0])
                _loss = criterion(_prediction, data[1])
                v_loss.append(_loss)
        valid_loss.append(torch.tensor(v_loss).mean())

        #torch.save(model.state_dict(), f'epoch_{epoch}valloss{valid_loss[epoch]:.3f}.pt')
        print(f"Loss = {train_loss[epoch]:.5f},\t val_loss = {valid_loss[epoch]:.5f}")
# Out:
# Epoch 1/500
# Loss = 0.69552,	 val_loss = 0.65729
# Epoch 2/500
# Loss = 0.60147,	 val_loss = 0.56585
# Epoch 3/500
# Loss = 0.54621,	 val_loss = 0.53383
# Epoch 4/500
# Loss = 0.52141,	 val_loss = 0.51278
# Epoch 5/500
# Loss = 0.50172,	 val_loss = 0.49437
# Epoch 6/500
# Loss = 0.48367,	 val_loss = 0.47699
# Epoch 7/500
# Loss = 0.46679,	 val_loss = 0.46083
# Epoch 8/500
# Loss = 0.45115,	 val_loss = 0.44601
# Epoch 9/500
# Loss = 0.43695,	 val_loss = 0.43259
# Epoch 10/500
# Loss = 0.42415,	 val_loss = 0.42062
# Epoch 11/500
# Loss = 0.41263,	 val_loss = 0.40969
# Epoch 12/500
# Loss = 0.40225,	 val_loss = 0.39986
# Epoch 13/500
# Loss = 0.39287,	 val_loss = 0.39097
# Epoch 14/500
# Loss = 0.38439,	 val_loss = 0.38284
# Epoch 15/500
# Loss = 0.37668,	 val_loss = 0.37541
# Epoch 16/500
# Loss = 0.36969,	 val_loss = 0.36871
# Epoch 17/500
# Loss = 0.36335,	 val_loss = 0.36275
# Epoch 18/500
# Loss = 0.35768,	 val_loss = 0.35727
# Epoch 19/500
# Loss = 0.35255,	 val_loss = 0.35260
# Epoch 20/500
# Loss = 0.34794,	 val_loss = 0.34825
# Epoch 21/500
# Loss = 0.34378,	 val_loss = 0.34439
# Epoch 22/500
# Loss = 0.34013,	 val_loss = 0.34090
# Epoch 23/500
# Loss = 0.33687,	 val_loss = 0.33785
# Epoch 24/500
# Loss = 0.33397,	 val_loss = 0.33533
# Epoch 25/500
# Loss = 0.33140,	 val_loss = 0.33293
# Epoch 26/500
# Loss = 0.32909,	 val_loss = 0.33081
# Epoch 27/500
# Loss = 0.32712,	 val_loss = 0.32886
# Epoch 28/500
# Loss = 0.32534,	 val_loss = 0.32725
# Epoch 29/500
# Loss = 0.32379,	 val_loss = 0.32597
# Epoch 30/500
# Loss = 0.32243,	 val_loss = 0.32460
# Epoch 31/500
# Loss = 0.32125,	 val_loss = 0.32343
# Epoch 32/500
# Loss = 0.32021,	 val_loss = 0.32254
# Epoch 33/500
# Loss = 0.31928,	 val_loss = 0.32164
# Epoch 34/500
# Loss = 0.31847,	 val_loss = 0.32094
# Epoch 35/500
# Loss = 0.31775,	 val_loss = 0.32045
# Epoch 36/500
# Loss = 0.31713,	 val_loss = 0.31984
# Epoch 37/500
# Loss = 0.31658,	 val_loss = 0.31925
# Epoch 38/500
# Loss = 0.31615,	 val_loss = 0.31879
# Epoch 39/500
# Loss = 0.31568,	 val_loss = 0.31851
# Epoch 40/500
# Loss = 0.31527,	 val_loss = 0.31825
# Epoch 41/500
# Loss = 0.31494,	 val_loss = 0.31796
# Epoch 42/500
# Loss = 0.31459,	 val_loss = 0.31746
# Epoch 43/500
# Loss = 0.31434,	 val_loss = 0.31725
# Epoch 44/500
# Loss = 0.31404,	 val_loss = 0.31730
# Epoch 45/500
# Loss = 0.31380,	 val_loss = 0.31676
# Epoch 46/500
# Loss = 0.31355,	 val_loss = 0.31661
# Epoch 47/500
# Loss = 0.31336,	 val_loss = 0.31641
# Epoch 48/500
# Loss = 0.31315,	 val_loss = 0.31611
# Epoch 49/500
# Loss = 0.31296,	 val_loss = 0.31628
# Epoch 50/500
# Loss = 0.31273,	 val_loss = 0.31595
# Epoch 51/500
# Loss = 0.31264,	 val_loss = 0.31566
# Epoch 52/500
# Loss = 0.31244,	 val_loss = 0.31553
# Epoch 53/500
# Loss = 0.31226,	 val_loss = 0.31539
# Epoch 54/500
# Loss = 0.31209,	 val_loss = 0.31516
# Epoch 55/500
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [23], in <cell line: 9>()
#      10 print(f"Epoch {epoch + 1}/{n_epochs}")
#      11 t_loss = []
# ---> 12 for step, data in enumerate(train_dataloader):
#      13     optimizer.zero_grad()
#      14     prediction = model.forward(data[0])
#
# File ~\anaconda3\lib\site-packages\torch\utils\data\dataloader.py:631, in _BaseDataLoaderIter.__next__(self)
#     628 if self._sampler_iter is None:
#     629     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     630     self._reset()  # type: ignore[call-arg]
# --> 631 data = self._next_data()
#     632 self._num_yielded += 1
#     633 if self._dataset_kind == _DatasetKind.Iterable and \
#     634         self._IterableDataset_len_called is not None and \
#     635         self._num_yielded > self._IterableDataset_len_called:
#
# File ~\anaconda3\lib\site-packages\torch\utils\data\dataloader.py:675, in _SingleProcessDataLoaderIter._next_data(self)
#     673 def _next_data(self):
#     674     index = self._next_index()  # may raise StopIteration
# --> 675     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     676     if self._pin_memory:
#     677         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~\anaconda3\lib\site-packages\torch\utils\data\_utils\fetch.py:54, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
# ---> 54 return self.collate_fn(data)
#
# File ~\anaconda3\lib\site-packages\torch\utils\data\_utils\collate.py:316, in default_collate(batch)
#     255 def default_collate(batch):
#     256     r"""
#     257     Take in a batch of data and put the elements within the batch into a tensor with an additional outer dimension - batch size.
#     258
#    (...)
#     314         >>> default_collate(batch)  # Handle `CustomType` automatically
#     315     """
# --> 316     return collate(batch, collate_fn_map=default_collate_fn_map)
#
# File ~\anaconda3\lib\site-packages\torch\utils\data\_utils\collate.py:173, in collate(batch, collate_fn_map)
#     170 transposed = list(zip(*batch))  # It may be accessed twice, so we use a list.
#     172 if isinstance(elem, tuple):
# --> 173     return [collate(samples, collate_fn_map=collate_fn_map) for samples in transposed]  # Backwards compatibility.
#     174 else:
#     175     try:
#
# File ~\anaconda3\lib\site-packages\torch\utils\data\_utils\collate.py:173, in <listcomp>(.0)
#     170 transposed = list(zip(*batch))  # It may be accessed twice, so we use a list.
#     172 if isinstance(elem, tuple):
# --> 173     return [collate(samples, collate_fn_map=collate_fn_map) for samples in transposed]  # Backwards compatibility.
#     174 else:
#     175     try:
#
# File ~\anaconda3\lib\site-packages\torch\utils\data\_utils\collate.py:141, in collate(batch, collate_fn_map)
#     139 if collate_fn_map is not None:
#     140     if elem_type in collate_fn_map:
# --> 141         return collate_fn_map[elem_type](batch, collate_fn_map=collate_fn_map)
#     143     for collate_type in collate_fn_map:
#     144         if isinstance(elem, collate_type):
#
# File ~\anaconda3\lib\site-packages\torch\utils\data\_utils\collate.py:213, in collate_tensor_fn(batch, collate_fn_map)
#     211     storage = elem._typed_storage()._new_shared(numel, device=elem.device)
#     212     out = elem.new(storage).resize_(len(batch), *list(elem.size()))
# --> 213 return torch.stack(batch, 0, out=out)
#
# KeyboardInterrupt:

# %%
test_input, test_output = torch.tensor(X_test.values, dtype = torch.float).to(device),torch.tensor(y_test.values, dtype = torch.float).reshape(-1,1).to(device)

# %%
pred_output = model.forward(test_input)
pred_output.shape
# Out:
# torch.Size([129908, 1])

# %%
pred_output = pred_output.detach().cpu().numpy()
test_output = test_output.detach().cpu().numpy()
pred_output
# Out:
# array([[0.04217016],
#        [0.05315766],
#        [0.946144  ],
#        ...,
#        [0.07685518],
#        [0.70011324],
#        [0.02910971]], dtype=float32)

# %%
from sklearn.metrics import roc_curve
fpr, tpr, thresholds = roc_curve(test_output, pred_output)

# %%
from sklearn.metrics import auc
auc(fpr,tpr)
# Out:
# 0.9379828403266084

# %%
plt.plot(fpr,tpr)
plt.xlabel("false positive rate")
plt.ylabel("true positive rate")
plt.grid(True)
plt.title("ROC for classification with GJet Background")
plt.show()
plt.savefig("gjet_roc.png")

# %%
thresholds[(fpr>0.1999) & (fpr<0.2001)]
# Out:
# array([0.38521755, 0.38521132, 0.38520133, 0.38514695, 0.38510898,
#        0.3850859 , 0.38506913, 0.38505706, 0.384974  , 0.38494235,
#        0.3849083 , 0.38486964], dtype=float32)

# %%
sig = pred_output[test_output ==1]
bkg = pred_output[test_output==0]
plt.hist(sig,bins = 50,range=(0,1),label = "Signal",density = True)
plt.hist(bkg,bins = 50,range=(0,1),label = "Background",density = True)
plt.title("Signal-Background separation in case of GJet Background")
plt.grid(True)
plt.legend(frameon=True)
plt.show()
plt.savefig("GJet_sep.png")

# %%
from sklearn.metrics import accuracy_score
mask = pred_output > 0.385
pred_output[mask] = 1
pred_output[~mask] = 0
accuracy_score(test_output,pred_output)
# Out:
# 0.8673676755857992
